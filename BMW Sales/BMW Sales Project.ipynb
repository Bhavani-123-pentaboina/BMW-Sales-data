# %% [raw]
# 🚗🚗 BMW Sales Data 🚗🚗

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ♦️ LOADING

# %%
df = pd.read_csv(r'C:\\Users\\P Bhavani\\OneDrive\\Desktop\\BMW sales data .csv', delimiter=',')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Model                 50000 non-null  object
#  1   Year                  50000 non-null  int64
#  2   Region                50000 non-null  object
#  3   Color                 50000 non-null  object
#  4   Fuel_Type             50000 non-null  object
#  5   Transmission          50000 non-null  object
#  6   Engine_Size_L         50000 non-null  float64
#  7   Mileage_KM            50000 non-null  int64
#  8   Price_USD             50000 non-null  int64
#  9   Sales_Volume          50000 non-null  int64
#  10  Sales_Classification  50000 non-null  object
# dtypes: float64(1), int64(4), object(6)
# memory usage: 4.2+ MB

# %%
df.shape
# Out:
# (50000, 11)

# %%
df.drop_duplicates()
# Out:
#           Model  Year         Region   Color Fuel_Type Transmission  \
# 0      5 Series  2016           Asia     Red    Petrol       Manual
# 1            i8  2013  North America     Red    Hybrid    Automatic
# 2      5 Series  2022  North America    Blue    Petrol    Automatic
# 3            X3  2024    Middle East    Blue    Petrol    Automatic
# 4      7 Series  2020  South America   Black    Diesel       Manual
# ...         ...   ...            ...     ...       ...          ...
# 49995        i3  2014           Asia     Red    Hybrid       Manual
# 49996        i3  2023    Middle East  Silver  Electric       Manual
# 49997  5 Series  2010    Middle East     Red    Petrol    Automatic
# 49998        i3  2020           Asia   White  Electric    Automatic
# 49999        X1  2020  North America    Blue    Diesel       Manual
#
#        Engine_Size_L  Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# ...

# %%
df.size
# Out:
# 550000

# %%
df.head()
# Out:
#       Model  Year         Region  Color Fuel_Type Transmission  Engine_Size_L  \
# 0  5 Series  2016           Asia    Red    Petrol       Manual            3.5
# 1        i8  2013  North America    Red    Hybrid    Automatic            1.6
# 2  5 Series  2022  North America   Blue    Petrol    Automatic            4.5
# 3        X3  2024    Middle East   Blue    Petrol    Automatic            1.7
# 4  7 Series  2020  South America  Black    Diesel       Manual            2.1
#
#    Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 0      151748      98740          8300                 High
# 1      121671      79219          3428                  Low
# 2       10991     113265          6994                  Low
# 3       27255      60971          4047                  Low
# 4      122131      49898          3080                  Low

# %%
df.tail()
# Out:
#           Model  Year         Region   Color Fuel_Type Transmission  \
# 49995        i3  2014           Asia     Red    Hybrid       Manual
# 49996        i3  2023    Middle East  Silver  Electric       Manual
# 49997  5 Series  2010    Middle East     Red    Petrol    Automatic
# 49998        i3  2020           Asia   White  Electric    Automatic
# 49999        X1  2020  North America    Blue    Diesel       Manual
#
#        Engine_Size_L  Mileage_KM  Price_USD  Sales_Volume Sales_Classification
# 49995            4.6      151030      42932          8182                 High
# 49996            4.2      147396      48714          9816                 High
# 49997            4.5      174939      46126          8280                 High
# 49998            3.8        3379      58566          9486                 High
# 49999            3.3      171003      77492          1764                  Low

# %%
df.describe()
# Out:
#                Year  Engine_Size_L     Mileage_KM      Price_USD  Sales_Volume
# count  50000.000000   50000.000000   50000.000000   50000.000000  50000.000000
# mean    2017.015700       3.247180  100307.203140   75034.600900   5067.514680
# std        4.324459       1.009078   57941.509344   25998.248882   2856.767125
# min     2010.000000       1.500000       3.000000   30000.000000    100.000000
# 25%     2013.000000       2.400000   50178.000000   52434.750000   2588.000000
# 50%     2017.000000       3.200000  100388.500000   75011.500000   5087.000000
# 75%     2021.000000       4.100000  150630.250000   97628.250000   7537.250000
# max     2024.000000       5.000000  199996.000000  119998.000000   9999.000000

# %%
df.nunique()
# Out:
# Model                      11
# Year                       15
# Region                      6
# Color                       6
# Fuel_Type                   4
# Transmission                2
# Engine_Size_L              36
# Mileage_KM              44347
# Price_USD               38246
# Sales_Volume             9845
# Sales_Classification        2
# dtype: int64

# %%
df.isnull().sum()
# Out:
# Model                   0
# Year                    0
# Region                  0
# Color                   0
# Fuel_Type               0
# Transmission            0
# Engine_Size_L           0
# Mileage_KM              0
# Price_USD               0
# Sales_Volume            0
# Sales_Classification    0
# dtype: int64

# %% [markdown]
# ♦️  ANALYSIS

# %%
# Sales by Year
sales_by_year = df.groupby('Year')['Sales_Volume'].sum()
print("--- Sales by Year ---")
print(sales_by_year.head())
# Out:
# --- Sales by Year ---
# Year
# 2010    16933445
# 2011    16758941
# 2012    16751895
# 2013    16866733
# 2014    16958960
# Name: Sales_Volume, dtype: int64

# %%
# Top 10 Models
top_models = df.groupby('Model')['Sales_Volume'].sum().sort_values(ascending=False).head(10)
print("--- Top 10 Models ---")
print(top_models)
# Out:
# --- Top 10 Models ---
# Model
# 7 Series    23786466
# i8          23423891
# X1          23406060
# 3 Series    23281303
# i3          23133849
# 5 Series    23097519
# M5          22779688
# X3          22745529
# X5          22709749
# X6          22661986
# Name: Sales_Volume, dtype: int64

# %%
# Sales by Region
sales_by_region = df.groupby('Region')['Sales_Volume'].sum().sort_values(ascending=False)
print("--- Sales by Region ---")
print(sales_by_region)
# Out:
# --- Sales by Region ---
# Region
# Asia             42974277
# Europe           42555138
# North America    42402629
# Middle East      42326620
# Africa           41565252
# South America    41551818
# Name: Sales_Volume, dtype: int64

# %% [markdown]
# ♦️  VISUALIZATIONS

# %%
# LINE GRAPH
# Sales Volume Vs Years
plt.plot(sales_by_year.index, sales_by_year.values, marker="o", color="blue")
plt.title("BMW Sales Volume Over Years")
plt.xlabel("Year")
plt.ylabel("Total Sales Volume")
plt.show()

# %%
# BAR GRAPH
# Total sales Volume vs Model (BAR GRAPH)
top_models.plot(kind="bar", color="skyblue")
plt.title("Top 10 BMW Models by Sales Volume")
plt.xlabel("Model")
plt.ylabel("Total Sales Volume")
plt.show()

# %%
#  HORIZONTAL BAR GRAPH
sales_by_region = df.groupby("Region")["Sales_Volume"].sum().sort_values()
sales_by_region.plot(kind="barh", color="purple")
plt.title("BMW Sales by Region")
plt.xlabel("Sales Volume")
plt.show()

# %%
# PIE CHART
sales_by_fuel = df.groupby("Fuel_Type")["Sales_Volume"].sum()
sales_by_fuel.plot(kind="pie", autopct="%1.1f%%", startangle=90, colormap="Set3")
plt.title("BMW Sales Distribution by Fuel Type")
plt.ylabel("")
plt.show()

# %%
# BOX PLOT
sns.boxplot(data=df, x="Transmission", y="Sales_Volume")
plt.title("Sales Volume Distribution by Transmission Type")
plt.show()

# %%
# HISTOGRAM
plt.hist(df["Price_USD"], bins=30, color="skyblue", edgecolor="black")
plt.title("Distribution of Car Prices")
plt.xlabel("Price (USD)")
plt.ylabel("Frequency")
plt.show()

# %%
# HISTOGRAM
plt.hist(df["Mileage_KM"], bins=30, color="lightgreen", edgecolor="black")
plt.title("Distribution of Mileage")
plt.xlabel("Mileage (KM)")
plt.ylabel("Frequency")
plt.show()

# %%
# Correlation Heatmap
corr = df.corr(numeric_only=True)
sns.heatmap(corr, annot=True, cmap="coolwarm", fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
# Heat map
pivot = df.pivot_table(values="Price_USD", index="Fuel_Type", columns="Transmission", aggfunc="mean")
sns.heatmap(pivot, annot=True, cmap="YlGnBu", fmt=".0f")
plt.title("Average Price by Fuel Type & Transmission")
plt.show()

# %%
# SCATTERPLOT
#Year vs Price
plt.scatter(df['Year'], df['Price_USD'], alpha=0.6, c="brown", edgecolor="k")
plt.xlabel("Year")
plt.ylabel("Price (USD)")
plt.title("Scatter Plot: Year vs Price")
plt.show()

# %%
# Pie Chart
# Sales by Region
sales_by_region = df.groupby('Region')['Sales_Volume'].sum()
sales_by_region.plot(kind='pie', autopct='%1.1f%%', colormap="Set3")
plt.ylabel("")  # remove y-label
plt.title("BMW Sales Distribution by Region")
plt.show()

# %%
# Area Chart
# Sales Volume by Year & Region
sales_area = df.groupby(["Year", "Region"])["Sales_Volume"].sum().unstack()
sales_area.plot(kind="area", stacked=True, alpha=0.6, colormap="tab20")
plt.title("BMW Sales Volume Over Years (by Region)")
plt.xlabel("Year")
plt.ylabel("Sales Volume")
plt.legend(title="Region", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %%
# Stacked Bar Chart 
# Sales by Fuel & Transmission
stacked_data = df.groupby(["Fuel_Type", "Transmission"])["Sales_Volume"].sum().unstack()
stacked_data.plot(kind="bar", stacked=True, figsize=(10, 6), colormap="Set2")
plt.title("BMW Sales Volume by Fuel Type & Transmission")
plt.xlabel("Fuel Type")
plt.ylabel("Sales Volume")
plt.legend(title="Transmission", bbox_to_anchor=(1.05, 1), loc="upper left")
plt.show()

# %% [markdown]
# ♦️ KEY INSIGHTS

# %% [raw]
# ° Low Cost BMW models are sold most, while expensive ones sell less but keep the brand’s image strong.
# ° More people prefer Automatic cars, and fewer are buying Manual ones.
# ° Petrol and Diesel are common, but Hybrid/Electric cars are slowly getting popular, especially in costly models.
# ° Cars with more kilometers driven are cheaper, while bigger engines cost more.
# ° Some regions buy most BMWs, while others are still small but growing markets.
